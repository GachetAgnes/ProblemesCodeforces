# %%
no_chateaux = 4
coord_chateaux = {}

# 0 0 1 2
# 0 2 1 3
# 1 0 2 1
# 1 1 2 3

# %%
for i in range(no_chateaux):
    a = input()
    a = a.split()
    a = list(map(int, a))
    coord_chateaux[f'Chateau {i}'] = a
# Out:
# 0 0 1 2
# 0 2 1 3
# 1 0 2 1
# 1 1 2 3

# %%
for key in coord_chateaux:
    print(f'{key} a la valeur : {coord_chateaux[key]}')
# Out:
# Chateau 0 a la valeur : [0, 0, 1, 2]
# Chateau 1 a la valeur : [0, 2, 1, 3]
# Chateau 2 a la valeur : [1, 0, 2, 1]
# Chateau 3 a la valeur : [1, 1, 2, 3]

# %%
def find_coords(a, b):
    c = [b[0], a[0]]
    d = [a[1], b[1]]
    return c, d

# %%
import math
def find_dist(args):
    a = args[0]
    c = args[1]
    b = args[2]
    d = args[3]
    #print(args[1])
    return math.sqrt(math.pow((d[0]-a[0]),2) + math.pow((d[1]-a[1]),2)), math.sqrt(math.pow((b[0]-a[0]),2) + math.pow((b[1]-a[1]),2))

# %%
for i in coord_chateaux:
    a = [] 
    b = []
    a = coord_chateaux[i]
    b = a[2:4]
    a = a[:2]
    c, d = find_coords(a, b)
    e = [a, b, c, d]
    f = find_dist(e)
    print(f'{i} a la valeur : {e}, {f}')
# Out:
# Chateau 0 a la valeur : [[0, 0], [1, 2], [1, 0], [0, 2]], (2.0, 1.0)
# Chateau 1 a la valeur : [[0, 2], [1, 3], [1, 0], [2, 3]], (2.23606797749979, 2.23606797749979)
# Chateau 2 a la valeur : [[1, 0], [2, 1], [2, 1], [0, 1]], (1.4142135623730951, 1.4142135623730951)
# Chateau 3 a la valeur : [[1, 1], [2, 3], [2, 1], [1, 3]], (2.0, 1.0)
